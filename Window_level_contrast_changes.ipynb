# %%
import numpy as np
import matplotlib.pyplot as plt

def win_scale(data, wl, ww, dtype, out_range):
    """
    Scale pixel intensity data using specified window level, width, and intensity range.
    """
    data_new = np.empty(data.shape, dtype=np.double)
    data_new.fill(out_range[1]-1)
    data_new[data <= (wl-ww/2.0)] = out_range[0]
    data_new[(data>(wl-ww/2.0))&(data<=(wl+ww/2.0))] = \
        ((data[(data>(wl-ww/2.0))&(data<=(wl+ww/2.0))]-(wl-0.5))/(ww-1.0)+0.5)*(out_range[1]-out_range[0])+out_range[0]
    data_new[data > (wl+ww/2.0)] = out_range[1]-1
    return data_new.astype(dtype)

def adjust_window_level(data, wl, ww, dtype=np.uint8, out_range=(0, 255)):
    """
    Adjust window level settings of a dataset.
    """
    adjusted_data = []
    for image in data:
        adjusted_data.append(win_scale(image, wl, ww, dtype, out_range))
    return np.stack(adjusted_data)

dataset = np.load('/raid/mpsych/OMAMA/DATA/data/2d_resized_512/images/10195895820725132694762818055891556958.npz')

image_data = dataset['data']

# Define your desired window level (wl) and window width (ww) values
# Adjust these values according to the characteristics of your dataset
wl = 2700
ww = 800

# Adjust window level settings of the dataset
adjusted_dataset = adjust_window_level(image_data, wl, ww)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image_data, cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(adjusted_dataset, cmap='gray')
plt.title('Adjusted Contrast')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def win_scale(data, wl, ww, dtype, out_range):
    """
    Scale pixel intensity data using specified window level, width, and intensity range.
    """
    data_new = np.empty(data.shape, dtype=np.double)
    data_new.fill(out_range[1]-1)
    data_new[data <= (wl-ww/2.0)] = out_range[0]
    data_new[(data>(wl-ww/2.0))&(data<=(wl+ww/2.0))] = \
        ((data[(data>(wl-ww/2.0))&(data<=(wl+ww/2.0))]-(wl-0.5))/(ww-1.0)+0.5)*(out_range[1]-out_range[0])+out_range[0]
    data_new[data > (wl+ww/2.0)] = out_range[1]-1
    return data_new.astype(dtype)

def adjust_window_level(data, wl, ww, dtype=np.uint8, out_range=(0, 255)):
    """
    Adjust window level settings of a dataset.
    """
    adjusted_data = []
    for image in data:
        adjusted_data.append(win_scale(image, wl, ww, dtype, out_range))
    return np.stack(adjusted_data)

dataset = np.load('/raid/mpsych/OMAMA/DATA/data/2d_resized_512/images/10195895820725132694762818055891556958.npz')

image_data = dataset['data']

#Normal
wl = 2773
ww = 900

# Adjust window level settings of the dataset
adjusted_dataset = adjust_window_level(image_data, wl, ww)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image_data, cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(adjusted_dataset, cmap='gray')
plt.title('Adjusted Contrast')

plt.show()

# %%
nor = adjusted_dataset/255

# %%
nor.max()
# Out:
# 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt

def win_scale(data, wl, ww, dtype, out_range):
    """
    Scale pixel intensity data using specified window level, width, and intensity range.
    """
    data_new = np.empty(data.shape, dtype=np.double)
    data_new.fill(out_range[1]-1)
    data_new[data <= (wl-ww/2.0)] = out_range[0]
    data_new[(data>(wl-ww/2.0))&(data<=(wl+ww/2.0))] = \
        ((data[(data>(wl-ww/2.0))&(data<=(wl+ww/2.0))]-(wl-0.5))/(ww-1.0)+0.5)*(out_range[1]-out_range[0])+out_range[0]
    data_new[data > (wl+ww/2.0)] = out_range[1]-1
    return data_new.astype(dtype)

def adjust_window_level(data, wl, ww, dtype=np.uint8, out_range=(0, 255)):
    """
    Adjust window level settings of a dataset.
    """
    adjusted_data = []
    for image in data:
        adjusted_data.append(win_scale(image, wl, ww, dtype, out_range))
    return np.stack(adjusted_data)

dataset = np.load('/raid/mpsych/OMAMA/DATA/data/2d_resized_512/images/10195895820725132694762818055891556958.npz')

image_data = dataset['data']

# Harder
wl = 2815
ww = 750

# Adjust window level settings of the dataset
adjusted_dataset = adjust_window_level(image_data, wl, ww)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image_data, cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(adjusted_dataset, cmap='gray')
plt.title('Adjusted Contrast')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def win_scale(data, wl, ww, dtype, out_range):
    """
    Scale pixel intensity data using specified window level, width, and intensity range.
    """
    data_new = np.empty(data.shape, dtype=np.double)
    data_new.fill(out_range[1]-1)
    data_new[data <= (wl-ww/2.0)] = out_range[0]
    data_new[(data>(wl-ww/2.0))&(data<=(wl+ww/2.0))] = \
        ((data[(data>(wl-ww/2.0))&(data<=(wl+ww/2.0))]-(wl-0.5))/(ww-1.0)+0.5)*(out_range[1]-out_range[0])+out_range[0]
    data_new[data > (wl+ww/2.0)] = out_range[1]-1
    return data_new.astype(dtype)

def adjust_window_level(data, wl, ww, dtype=np.uint8, out_range=(0, 255)):
    """
    Adjust window level settings of a dataset.
    """
    adjusted_data = []
    for image in data:
        adjusted_data.append(win_scale(image, wl, ww, dtype, out_range))
    return np.stack(adjusted_data)

dataset = np.load('/raid/mpsych/OMAMA/DATA/data/2d_resized_512/images/10195895820725132694762818055891556958.npz')

image_data = dataset['data']

# Soft
wl = 2683
ww = 1050

# Adjust window level settings of the dataset
adjusted_dataset = adjust_window_level(image_data, wl, ww)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image_data, cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(adjusted_dataset, cmap='gray')
plt.title('Adjusted Contrast')

plt.show()
